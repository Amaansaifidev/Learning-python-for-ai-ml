# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaansaifidev/Learning-python-for-ai-ml/blob/master/Matplotlib-in-python/Mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = ["Monday", "Tuesday", "Wednesday","Thursday","Friday", "Saturday", "Sunday"]

# %%
y = [10, 20, 12, 18, 16, 15, 18]

# %%
plt.plot(x, y)
plt.title = "bakery shop sales"
plt.xlabel("days", fontsize=20, color="red")
plt.ylabel("sales", fontsize=20, color="red")
plt.show()

# %%
plt.plot(x, y, color="green")
plt.title = "bakery shop sales"
plt.xlabel("days", fontsize=20, color="red")
plt.ylabel("sales", fontsize=20, color="red")
plt.show()
